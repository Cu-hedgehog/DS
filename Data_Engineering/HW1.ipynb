# %%
import luigi
from luigi.util import requires, inherits
from luigi import Task, run, LocalTarget
import wget
import tarfile
import os
import gzip
import pandas as pd
import shutil
import io

# %%
class DownloadTask(Task):
    
    url = luigi.Parameter()
    NameDownload = luigi.Parameter()
    dir = luigi.Parameter()
    NameSave = luigi.Parameter()
    
    def run(self):
        fileurl = self.url + self.NameDownload
        wget.download(fileurl, self.output().path)
        
    def output(self):
        return luigi.LocalTarget(self.dir + self.NameSave)
        
@requires(DownloadTask)
class UnzipTar(Task):
    
    def run(self):
        in_file_path = self.input().path
        with tarfile.open(in_file_path, 'r') as tar:
            tar.extractall(self.dir)
    
    def output(self):
        if os.path.exists(self.dir + self.NameSave):
            result = []
            with tarfile.open(self.input().path, 'r') as tar:
                for i in tar.getnames():
                    result.append(luigi.LocalTarget(self.dir + i))
            return result
  
@requires(UnzipTar)
class UnzipGZ(Task):
    
    def run(self):
        # in_file_path = str(self.input())
        # dir_path = in_file_path[:in_file_path.rfind('/')+1]
        branch_count = 1
        
        for i in self.input():
            i = str(i.path)
            dir_name = str(branch_count) + 'branch'
            os.mkdir(self.dir + dir_name)
            with gzip.open(i, 'rb') as f_in:
                archive_name = self.dir + dir_name + '/' + i[i.rfind('/')+1:-2]
                with open(archive_name, 'wb') as f_out:
                    shutil.copyfileobj(f_in, f_out)
            branch_count += 1
    

# if __name__ == '__main__':
#     run()

# %%
params_dict = {'url': 'https://www.ncbi.nlm.nih.gov/geo/download/?acc=',
               'NameDownload': 'GSE68849&format=file',
               'dir': 'Root/',
               'NameSave': 'RootTAR.tar'}
luigi.build([UnzipTar(**params_dict)], workers=1, local_scheduler=True)
# Out:
# DEBUG: Checking if UnzipTar(url=https://www.ncbi.nlm.nih.gov/geo/download/?acc=, NameDownload=GSE68849&format=file, dir=Root/, NameSave=RootTAR.tar) is complete
# WARNING: Will not run UnzipTar(url=https://www.ncbi.nlm.nih.gov/geo/download/?acc=, NameDownload=GSE68849&format=file, dir=Root/, NameSave=RootTAR.tar) or any dependencies due to error in complete() method:
# Traceback (most recent call last):
#   File "c:\Users\smart\AppData\Local\Programs\Python\Python39\lib\site-packages\luigi\worker.py", line 441, in check_complete
#     is_complete = check_complete_cached(task, completion_cache)
#   File "c:\Users\smart\AppData\Local\Programs\Python\Python39\lib\site-packages\luigi\worker.py", line 426, in check_complete_cached
#     is_complete = task.complete()
#   File "c:\Users\smart\AppData\Local\Programs\Python\Python39\lib\site-packages\luigi\task.py", line 588, in complete
#     outputs = flatten(self.output())
#   File "C:\Users\smart\AppData\Local\Temp\ipykernel_66392\3275208203.py", line 25, in output
#     with tarfile.open(self.input().path, 'r') as tar:
#   File "c:\Users\smart\AppData\Local\Programs\Python\Python39\lib\tarfile.py", line 1611, in open
#     return func(name, "r", fileobj, **kwargs)
#   File "c:\Users\smart\AppData\Local\Programs\Python\Python39\lib\tarfile.py", line 1675, in gzopen
#     fileobj = GzipFile(name, mode + "b", compresslevel, fileobj)
#   File "c:\Users\smart\AppData\Local\Programs\Python\Python39\lib\gzip.py", line 173, in __init__
#     fileobj = self.myfileobj = builtins.open(filename, mode or 'rb')
# FileNotFoundError: [Errno 2] No such file or directory: 'Root/RootTAR.tar'
#
# INFO: Informed scheduler that task   UnzipTar_GSE68849_format__RootTAR_tar_Root__d963adad19   has status   UNKNOWN
# INFO: Done scheduling tasks
# INFO: Running Worker with 1 processes
# DEBUG: Asking scheduler for work...
# DEBUG: Done
# DEBUG: There are no more tasks to run at this time
# INFO: Worker Worker(salt=7013176932, workers=1, host=LAPTOP-UU6JICQO, username=smart, pid=66392) was stopped. Shutting down Keep-Alive thread
# INFO:
# ===== Luigi Execution Summary =====
#
# Scheduled 1 tasks of which:
# * 1 failed scheduling:
#     - 1 UnzipTar(url=https://www.ncbi.nlm.nih.gov/geo/download/?acc=, NameDownload=GSE68849&format=file, dir=Root/, NameSave=RootTAR.tar)
#
# Did not run any tasks
# This progress looks :( because there were tasks whose scheduling failed
#
# ===== Luigi Execution Summary =====
# False

# %%
dfs = {}
with gzip.open('Root/1 branch/GPL10558_HumanHT-12_V4_0_R1_15002873_B.txt.gz', 'rb') as f_in:
    with open('Root/1 branch/GPL10558_HumanHT-12_V4_0_R1_15002873_B.txt', 'wb') as f_out:
        shutil.copyfileobj(f_in, f_out)

# %%
str = 'Root/1 branch/GPL10558_HumanHT-12_V4_0_R1_15002873_B.txt.gz'
str[:-3]
# Out:
# 'Root/1 branch/GPL10558_HumanHT-12_V4_0_R1_15002873_B.txt'

# %%
dfs = {}
with open('Root/1 branch/GPL10558_HumanHT-12_V4_0_R1_15002873_B.txt') as f:
    write_key = None
    fio = io.StringIO()
    for l in f.readlines():
        if l.startswith('['):
            if write_key:
                fio.seek(0)
                header = None if write_key == 'Heading' else 'infer'
                dfs[write_key] = pd.read_csv(fio, sep='\t', header=header)
            fio = io.StringIO()
            write_key = l.strip('[]\n')
            continue
        if write_key:
            fio.write(l)
    fio.seek(0)
    dfs[write_key] = pd.read_csv(fio, sep='\t')

# %%
for i in dfs:
    dfs[i].to_csv('Root/1 branch/'+i+'.csv', index=False)

# %%
pd.read_csv('Root/1 branch/Probes.csv').head()

# %%
@requires(DownloadTask)
class UnzipTar(Task):
    
    def run(self):
        in_file_path = str(self.input())
        dir_path = in_file_path[:in_file_path.rfind('/')+1]
        branch_count = 1
        
        with tarfile.open(in_file_path, 'r') as tar:
            for i in tar.getnames():
                dir_name = str(branch_count) + 'branch'
                os.mkdir(dir_path + dir_name)
                tar.extract(i, dir_path + dir_name)
                archive_name = dir_path + dir_name + '/' + i
                with gzip.open(archive_name, 'rb') as f_in:
                    with open(archive_name[:-2], 'wb') as f_out:
                        shutil.copyfileobj(f_in, f_out)
                branch_count += 1
    
    def output(self):
        pass

# %%
from pathlib import Path

# %%
class DownloadTask2(Task):
    
    url = luigi.Parameter(default='https://www.ncbi.nlm.nih.gov/geo/download/?acc=')
    NameDownload = luigi.Parameter(default='GSE68849&format=file')
    dir = luigi.Parameter(default='Root/')
    NameSave = luigi.Parameter(default='Root.tar')
    
    def run(self):
        fileurl = self.url + self.NameDownload
        wget.download(fileurl, self.output().path)
        
    def output(self):
        return luigi.LocalTarget(self.dir + self.NameSave)
        
@requires(DownloadTask2)
class UnzipTar2(Task):
    
    def run(self):
        # in_file_path = self.input().path
        with tarfile.open(self.input().path, 'r') as tar:
            tar.extractall(self.dir)
    
    # def output(self):
    #     return luigi.LocalTarget(self.dir)
    def output(self):
        if os.path.exists(self.dir + self.NameSave):
            result = []
            with tarfile.open(self.input().path, 'r') as tar:
                for i in tar.getnames():
                    result.append(luigi.LocalTarget(self.dir + i))
            return result
  
#@requires(UnzipTar2)
class UnzipGZ2(Task):  
    
    dir = luigi.Parameter()
    file_name = luigi.Parameter()
    dir_num = luigi.IntParameter()
    
    def run(self):
        file_dir = self.dir + self.file_name
        with gzip.open(file_dir, 'rb') as f_in:
            dir_name = 'branch' + str(self.dir_num) + '/'
            os.mkdir(self.dir + dir_name)
            archive_name = self.dir + dir_name + self.file_name[:-3]
            with open(archive_name, 'wb') as f_out:
                shutil.copyfileobj(f_in, f_out)
                
    def output(self):
        result = self.dir + 'branch' + str(self.dir_num) + '/' + self.file_name[:-3]
        return luigi.LocalTarget(result)

#@inherits(DownloadTask2)
class UnzipTXT(Task):
    
    dir = luigi.Parameter(defuakt='/Root')
    
    def requires(self):
        #UnzipTar2(self.url, self.NameDownload, self.dir, self.NameSave)
        task = []
        j = 0
        for i in os.listdir(self.dir):
            i = str(i)
            if i[-3:] == '.gz':
                # params = {'url': self.url, 'NameDownlod': self.NameDownload,
                #           'dir': self.dir, 'NameSave': self.NameSave,
                #           'file_name': i, 'dir_num': j}
                params = {'dir': self.dir, 'file_name': i, 'dir_num': j}
                task.append(UnzipGZ2(**params))
                j += 1
        return task
    
    def run(self):
        # in_file_path = str(self.input())
        # dir_path = in_file_path[:in_file_path.rfind('/')+1]
        for i in self.input():
            dfs = {}
            with open(i.path) as f:
                write_key = None
                fio = io.StringIO()
                for l in f.readlines():
                    if l.startswith('['):
                        if write_key:
                            fio.seek(0)
                            header = None if write_key == 'Heading' else 'infer'
                            dfs[write_key] = pd.read_csv(fio, sep='\t', header=header)
                        fio = io.StringIO()
                        write_key = l.strip('[]\n')
                        continue
                    if write_key:
                        fio.write(l)
                fio.seek(0)
                dfs[write_key] = pd.read_csv(fio, sep='\t')
                
            for table in dfs:
                i_str = str(i)
                table_dir = i_str[:i_str.rfind('/')+1]
                dfs[table].to_csv(table_dir + table + '.csv', index=False)
                
    def output(self):
        result = []
        for i in os.listdir(self.dir):
            i = str(i)
            if i.startswith('branch'):
                result_str = self.dir + i
                result.append(luigi.LocalTarget(result_str))
        return result
        # if result: return result
        # else: return luigi.LocalTarget('123')

@requires(UnzipTXT)
class CleanProbes(Task):
    
    def run(self):
        clean_list = ['Definition', 'Ontology_Component', 'Ontology_Process', 
                      'Ontology_Function', 'Synonyms', 'Obsolete_Probe_Id', 'Probe_Sequence']
        for i in self.input():
            i = i.path
            for j in os.listdir(i):
                j = str(j)
                if j == 'Probes.csv':
                    df = pd.read_csv(str(i)+'/'+j)
                    df_col = df.columns.tolist()
                    df_col = list(set(df_col) - set(clean_list))
                    df = df[df_col]
                    df.to_csv(str(i)+'/Probes_clean.csv', index=False)
                    
    def output(self):
        result = []
        for i in os.listdir(self.dir):
            i = str(i)
            if i.startswith('branch'):
                result_str = self.dir + i
                result.append(luigi.LocalTarget(result_str +'/Probes_clean.csv'))
        
        return result
        # if result: return result
        # else: return luigi.LocalTarget('123')
    
@requires(CleanProbes)
class RemoveRoot(Task):
    def run(self):
        os.remove(self.dir + 'Root.tar')
        for i in os.listdir(self.dir):
            i = str(i)
            if i[-3:] == '.gz':
                os.remove(self.dir + i)
            if i.startswith('branch'):
                for j in os.listdir(self.dir + i):
                    j = str(j)
                    if j[-4:] == '.txt':
                        os.remove(self.dir + i + '/' + j)

# %%
params_dict = {'url': 'https://www.ncbi.nlm.nih.gov/geo/download/?acc=',
               'NameDownload': 'GSE68849&format=file',
               'dir': 'Root/',
               'NameSave': 'Root.tar'}
params_dict2 = {'dir': 'Root/'}

#luigi.build([UnzipTar2(**params_dict)], workers=1, local_scheduler=True)
# luigi.build([CleanProbes(**params_dict2)], workers=1, local_scheduler=True)
luigi.build([RemoveRoot(**params_dict2)], workers=1, local_scheduler=True)
# Out:
# DEBUG: Checking if RemoveRoot(dir=Root/) is complete
# c:\Users\smart\AppData\Local\Programs\Python\Python39\lib\site-packages\luigi\worker.py:426: UserWarning: Task RemoveRoot(dir=Root/) without outputs has no custom complete() method
#   is_complete = task.complete()
# DEBUG: Checking if CleanProbes(dir=Root/) is complete
# c:\Users\smart\AppData\Local\Programs\Python\Python39\lib\site-packages\luigi\worker.py:426: UserWarning: Task CleanProbes(dir=Root/) without outputs has no custom complete() method
#   is_complete = task.complete()
# INFO: Informed scheduler that task   RemoveRoot_Root__97bb7c3600   has status   PENDING
# DEBUG: Checking if UnzipTXT(dir=Root/) is complete
# c:\Users\smart\AppData\Local\Programs\Python\Python39\lib\site-packages\luigi\worker.py:426: UserWarning: Task UnzipTXT(dir=Root/) without outputs has no custom complete() method
#   is_complete = task.complete()
# INFO: Informed scheduler that task   CleanProbes_Root__97bb7c3600   has status   PENDING
# DEBUG: Checking if UnzipGZ2(dir=Root/, file_name=GPL10558_HumanHT-12_V4_0_R1_15002873_B.txt.gz, dir_num=0) is complete
# DEBUG: Checking if UnzipGZ2(dir=Root/, file_name=GPL10558_HumanHT-12_V4_0_R2_15002873_B.txt.gz, dir_num=1) is complete
# INFO: Informed scheduler that task   UnzipTXT_Root__97bb7c3600   has status   PENDING
# INFO: Informed scheduler that task   UnzipGZ2_Root__1_GPL10558_HumanHT_6700629201   has status   PENDING
# INFO: Informed scheduler that task   UnzipGZ2_Root__0_GPL10558_HumanHT_38d87e180b   has status   PENDING
# INFO: Done scheduling tasks
# INFO: Running Worker with 1 processes
# DEBUG: Asking scheduler for work...
# DEBUG: Pending tasks: 5
# INFO: [pid 21396] Worker Worker(salt=4186396225, workers=1, host=LAPTOP-UU6JICQO, username=smart, pid=21396) running   UnzipGZ2(dir=Root/, file_name=GPL10558_HumanHT-12_V4_0_R2_15002873_B.txt.gz, dir_num=1)
# INFO: [pid 21396] Worker Worker(salt=4186396225, workers=1, host=LAPTOP-UU6JICQO, username=smart, pid=21396) done      UnzipGZ2(dir=Root/, file_name=GPL10558_HumanHT-12_V4_0_R2_15002873_B.txt.gz, dir_num=1)
# DEBUG: 1 running tasks, waiting for next task to finish
# INFO: Informed scheduler that task   UnzipGZ2_Root__1_GPL10558_HumanHT_6700629201   has status   DONE
# DEBUG: Asking scheduler for work...
# DEBUG: Pending tasks: 4
# INFO: [pid 21396] Worker Worker(salt=4186396225, workers=1, host=LAPTOP-UU6JICQO, username=smart, pid=21396) running   UnzipGZ2(dir=Root/, file_name=GPL10558_HumanHT-12_V4_0_R1_15002873_B.txt.gz, dir_num=0)
# INFO: [pid 21396] Worker Worker(salt=4186396225, workers=1, host=LAPTOP-UU6JICQO, username=smart, pid=21396) done      UnzipGZ2(dir=Root/, file_name=GPL10558_HumanHT-12_V4_0_R1_15002873_B.txt.gz, dir_num=0)
# DEBUG: 1 running tasks, waiting for next task to finish
# INFO: Informed scheduler that task   UnzipGZ2_Root__0_GPL10558_HumanHT_38d87e180b   has status   DONE
# DEBUG: Asking scheduler for work...
# DEBUG: Pending tasks: 3
# INFO: [pid 21396] Worker Worker(salt=4186396225, workers=1, host=LAPTOP-UU6JICQO, username=smart, pid=21396) running   UnzipTXT(dir=Root/)
# INFO: [pid 21396] Worker Worker(salt=4186396225, workers=1, host=LAPTOP-UU6JICQO, username=smart, pid=21396) done      UnzipTXT(dir=Root/)
# DEBUG: 1 running tasks, waiting for next task to finish
# INFO: Informed scheduler that task   UnzipTXT_Root__97bb7c3600   has status   DONE
# DEBUG: Asking scheduler for work...
# DEBUG: Pending tasks: 2
# INFO: [pid 21396] Worker Worker(salt=4186396225, workers=1, host=LAPTOP-UU6JICQO, username=smart, pid=21396) running   CleanProbes(dir=Root/)
# INFO: [pid 21396] Worker Worker(salt=4186396225, workers=1, host=LAPTOP-UU6JICQO, username=smart, pid=21396) done      CleanProbes(dir=Root/)
# DEBUG: 1 running tasks, waiting for next task to finish
# INFO: Informed scheduler that task   CleanProbes_Root__97bb7c3600   has status   DONE
# DEBUG: Asking scheduler for work...
# DEBUG: Pending tasks: 1
# INFO: [pid 21396] Worker Worker(salt=4186396225, workers=1, host=LAPTOP-UU6JICQO, username=smart, pid=21396) running   RemoveRoot(dir=Root/)
# INFO: [pid 21396] Worker Worker(salt=4186396225, workers=1, host=LAPTOP-UU6JICQO, username=smart, pid=21396) done      RemoveRoot(dir=Root/)
# DEBUG: 1 running tasks, waiting for next task to finish
# INFO: Informed scheduler that task   RemoveRoot_Root__97bb7c3600   has status   DONE
# DEBUG: Asking scheduler for work...
# DEBUG: Done
# DEBUG: There are no more tasks to run at this time
# INFO: Worker Worker(salt=4186396225, workers=1, host=LAPTOP-UU6JICQO, username=smart, pid=21396) was stopped. Shutting down Keep-Alive thread
# INFO:
# ===== Luigi Execution Summary =====
#
# Scheduled 5 tasks of which:
# * 5 ran successfully:
#     - 1 CleanProbes(dir=Root/)
#     - 1 RemoveRoot(dir=Root/)
#     - 2 UnzipGZ2(dir=Root/, file_name=GPL10558_HumanHT-12_V4_0_R1_15002873_B.txt.gz, dir_num=0) and UnzipGZ2(dir=Root/, file_name=GPL10558_HumanHT-12_V4_0_R2_15002873_B.txt.gz, dir_num=1)
#     - 1 UnzipTXT(dir=Root/)
#
# This progress looks :) because there were no failed tasks or missing dependencies
#
# ===== Luigi Execution Summary =====
# True
